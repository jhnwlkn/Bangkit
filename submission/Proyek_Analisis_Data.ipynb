# %% [markdown]
# # Proyek Analisis Data: Air Quality Dataset
# - **Nama:** John Wilken Christoper Nainggolan
# - **Email:** m248d4ky2232@bangkit.academy
# - **ID Dicoding:** johnwilken

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Apakah ada perbedaan signifikan dalam kualitas udara antara stasiun-stasiun yang berbeda?
# - Pada stasiun mana suhu mencapai derajat terendah dan tertingginya?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
# !pip install streamlit

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import streamlit as st
from babel.numbers import format_currency
from scipy.stats import f_oneway

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
data_aotizhongxin_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Dataset Final Project Dicoding/Air-quality-dataset/PRSA_Data_20130301-20170228/PRSA_Data_Aotizhongxin_20130301-20170228.csv')
data_aotizhongxin_df
# Out:
#           No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  \
# 0          1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0
# 1          2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0
# 2          3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0
# 3          4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0
# 4          5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0
# ...      ...   ...    ...  ...   ...    ...   ...   ...   ...    ...   ...
# 35059  35060  2017      2   28    19   12.0  29.0   5.0  35.0  400.0  95.0
# 35060  35061  2017      2   28    20   13.0  37.0   7.0  45.0  500.0  81.0
# 35061  35062  2017      2   28    21   16.0  37.0  10.0  66.0  700.0  58.0
# 35062  35063  2017      2   28    22   21.0  44.0  12.0  87.0  700.0  35.0
# 35063  35064  2017      2   28    23   19.0  31.0  10.0  79.0  600.0  42.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM       station
# ...

# %%
data_changping_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Dataset Final Project Dicoding/Air-quality-dataset/PRSA_Data_20130301-20170228/PRSA_Data_Changping_20130301-20170228.csv')
data_changping_df
# Out:
#           No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  \
# 0          1  2013      3    1     0    3.0   6.0  13.0   7.0  300.0  85.0
# 1          2  2013      3    1     1    3.0   3.0   6.0   6.0  300.0  85.0
# 2          3  2013      3    1     2    3.0   3.0  22.0  13.0  400.0  74.0
# 3          4  2013      3    1     3    3.0   6.0  12.0   8.0  300.0  81.0
# 4          5  2013      3    1     4    3.0   3.0  14.0   8.0  300.0  81.0
# ...      ...   ...    ...  ...   ...    ...   ...   ...   ...    ...   ...
# 35059  35060  2017      2   28    19   28.0  47.0   4.0  14.0  300.0   NaN
# 35060  35061  2017      2   28    20   12.0  12.0   3.0  23.0  500.0  64.0
# 35061  35062  2017      2   28    21    7.0  23.0   5.0  17.0  500.0  68.0
# 35062  35063  2017      2   28    22   11.0  20.0   3.0  15.0  500.0  72.0
# 35063  35064  2017      2   28    23   20.0  25.0   6.0  28.0  900.0  54.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM    station
# ...

# %%
data_dingling_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Dataset Final Project Dicoding/Air-quality-dataset/PRSA_Data_20130301-20170228/PRSA_Data_Dingling_20130301-20170228.csv')
data_dingling_df
# Out:
#           No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO     O3  \
# 0          1  2013      3    1     0    4.0   4.0  3.0  NaN  200.0   82.0
# 1          2  2013      3    1     1    7.0   7.0  3.0  NaN  200.0   80.0
# 2          3  2013      3    1     2    5.0   5.0  3.0  2.0  200.0   79.0
# 3          4  2013      3    1     3    6.0   6.0  3.0  NaN  200.0   79.0
# 4          5  2013      3    1     4    5.0   5.0  3.0  NaN  200.0   81.0
# ...      ...   ...    ...  ...   ...    ...   ...  ...  ...    ...    ...
# 35059  35060  2017      2   28    19   11.0  11.0  2.0  2.0  200.0   99.0
# 35060  35061  2017      2   28    20   13.0  13.0  2.0  2.0  200.0  101.0
# 35061  35062  2017      2   28    21    9.0  14.0  2.0  2.0  200.0  102.0
# 35062  35063  2017      2   28    22   10.0  12.0  2.0  2.0  200.0   97.0
# 35063  35064  2017      2   28    23   13.0  16.0  4.0  9.0  500.0   74.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM   station
# ...

# %%
data_dongsi_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Dataset Final Project Dicoding/Air-quality-dataset/PRSA_Data_20130301-20170228/PRSA_Data_Dongsi_20130301-20170228.csv')
data_dongsi_df
# Out:
#           No  year  month  day  hour  PM2.5  PM10   SO2   NO2      CO    O3  \
# 0          1  2013      3    1     0    9.0   9.0   3.0  17.0   300.0  89.0
# 1          2  2013      3    1     1    4.0   4.0   3.0  16.0   300.0  88.0
# 2          3  2013      3    1     2    7.0   7.0   NaN  17.0   300.0  60.0
# 3          4  2013      3    1     3    3.0   3.0   5.0  18.0     NaN   NaN
# 4          5  2013      3    1     4    3.0   3.0   7.0   NaN   200.0  84.0
# ...      ...   ...    ...  ...   ...    ...   ...   ...   ...     ...   ...
# 35059  35060  2017      2   28    19   16.0  51.0   3.0  29.0   400.0  73.0
# 35060  35061  2017      2   28    20   18.0  45.0   3.0  43.0   500.0  54.0
# 35061  35062  2017      2   28    21   23.0  58.0   5.0  61.0   700.0  28.0
# 35062  35063  2017      2   28    22   23.0  53.0   9.0  75.0   900.0  15.0
# 35063  35064  2017      2   28    23   30.0  71.0  11.0  87.0  1200.0   4.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM station
# ...

# %%
data_guanyuan_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Dataset Final Project Dicoding/Air-quality-dataset/PRSA_Data_20130301-20170228/PRSA_Data_Guanyuan_20130301-20170228.csv')
data_guanyuan_df
# Out:
#           No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  \
# 0          1  2013      3    1     0    4.0   4.0  14.0  20.0  300.0  69.0
# 1          2  2013      3    1     1    4.0   4.0  13.0  17.0  300.0  72.0
# 2          3  2013      3    1     2    3.0   3.0  10.0  19.0  300.0  69.0
# 3          4  2013      3    1     3    3.0   6.0   7.0  24.0  400.0  62.0
# 4          5  2013      3    1     4    3.0   6.0   5.0  14.0  400.0  71.0
# ...      ...   ...    ...  ...   ...    ...   ...   ...   ...    ...   ...
# 35059  35060  2017      2   28    19   13.0  37.0   3.0  36.0  400.0  60.0
# 35060  35061  2017      2   28    20   20.0  43.0   4.0  48.0  500.0  43.0
# 35061  35062  2017      2   28    21   16.0  33.0   5.0  39.0  500.0  50.0
# 35062  35063  2017      2   28    22   11.0  24.0   5.0  47.0  500.0  41.0
# 35063  35064  2017      2   28    23   15.0  27.0   5.0  53.0  600.0  33.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM   station
# ...

# %%
data_gucheng_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Dataset Final Project Dicoding/Air-quality-dataset/PRSA_Data_20130301-20170228/PRSA_Data_Gucheng_20130301-20170228.csv')
data_gucheng_df
# Out:
#           No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  \
# 0          1  2013      3    1     0    6.0  18.0  5.0   NaN  800.0  88.0
# 1          2  2013      3    1     1    6.0  15.0  5.0   NaN  800.0  88.0
# 2          3  2013      3    1     2    5.0  18.0  NaN   NaN  700.0  52.0
# 3          4  2013      3    1     3    6.0  20.0  6.0   NaN    NaN   NaN
# 4          5  2013      3    1     4    5.0  17.0  5.0   NaN  600.0  73.0
# ...      ...   ...    ...  ...   ...    ...   ...  ...   ...    ...   ...
# 35059  35060  2017      2   28    19   14.0  58.0  4.0  19.0  500.0  56.0
# 35060  35061  2017      2   28    20   27.0  83.0  6.0  60.0  700.0  26.0
# 35061  35062  2017      2   28    21   22.0  37.0  7.0  52.0  600.0  27.0
# 35062  35063  2017      2   28    22    9.0  23.0  3.0  13.0  400.0  57.0
# 35063  35064  2017      2   28    23   12.0  48.0  5.0  48.0  600.0  28.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM  station
# ...

# %%
data_huairou_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Dataset Final Project Dicoding/Air-quality-dataset/PRSA_Data_20130301-20170228/PRSA_Data_Huairou_20130301-20170228.csv')
data_huairou_df
# Out:
#           No  year  month  day  hour  PM2.5  PM10  SO2   NO2      CO    O3  \
# 0          1  2013      3    1     0    7.0   7.0  3.0   2.0   100.0  91.0
# 1          2  2013      3    1     1    4.0   4.0  3.0   NaN   100.0  92.0
# 2          3  2013      3    1     2    4.0   4.0  NaN   NaN   100.0  91.0
# 3          4  2013      3    1     3    3.0   3.0  3.0   2.0     NaN   NaN
# 4          5  2013      3    1     4    3.0   3.0  7.0   NaN   300.0  86.0
# ...      ...   ...    ...  ...   ...    ...   ...  ...   ...     ...   ...
# 35059  35060  2017      2   28    19   16.0  28.0  2.0  19.0   300.0  95.0
# 35060  35061  2017      2   28    20   21.0  34.0  4.0  24.0   500.0  80.0
# 35061  35062  2017      2   28    21   17.0  33.0  2.0  39.0   900.0  60.0
# 35062  35063  2017      2   28    22   11.0  29.0  3.0  32.0  1400.0  69.0
# 35063  35064  2017      2   28    23   11.0  20.0  2.0  27.0   400.0  77.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM  station
# ...

# %%
data_nongzhanguan_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Dataset Final Project Dicoding/Air-quality-dataset/PRSA_Data_20130301-20170228/PRSA_Data_Nongzhanguan_20130301-20170228.csv')
data_nongzhanguan_df
# Out:
#           No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  \
# 0          1  2013      3    1     0    5.0  14.0  4.0  12.0  200.0  85.0
# 1          2  2013      3    1     1    8.0  12.0  6.0  14.0  200.0  84.0
# 2          3  2013      3    1     2    3.0   6.0  5.0  14.0  200.0  83.0
# 3          4  2013      3    1     3    5.0   5.0  5.0  14.0  200.0  84.0
# 4          5  2013      3    1     4    5.0   5.0  6.0  21.0  200.0  77.0
# ...      ...   ...    ...  ...   ...    ...   ...  ...   ...    ...   ...
# 35059  35060  2017      2   28    19   14.0  21.0  3.0  27.0  400.0  72.0
# 35060  35061  2017      2   28    20   18.0  27.0  3.0  37.0  400.0  59.0
# 35061  35062  2017      2   28    21   15.0  39.0  5.0  50.0  600.0  41.0
# 35062  35063  2017      2   28    22   11.0  35.0  6.0  49.0  500.0  41.0
# 35063  35064  2017      2   28    23   10.0  28.0  7.0  48.0  600.0  39.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM       station
# ...

# %%
data_shunyi_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Dataset Final Project Dicoding/Air-quality-dataset/PRSA_Data_20130301-20170228/PRSA_Data_Shunyi_20130301-20170228.csv')
data_shunyi_df
# Out:
#           No  year  month  day  hour  PM2.5  PM10   SO2   NO2      CO    O3  \
# 0          1  2013      3    1     0    3.0   6.0   3.0   8.0   300.0  44.0
# 1          2  2013      3    1     1   12.0  12.0   3.0   7.0   300.0  47.0
# 2          3  2013      3    1     2   14.0  14.0   NaN   7.0   200.0  22.0
# 3          4  2013      3    1     3   12.0  12.0   3.0   5.0     NaN   NaN
# 4          5  2013      3    1     4   12.0  12.0   3.0   NaN   200.0  11.0
# ...      ...   ...    ...  ...   ...    ...   ...   ...   ...     ...   ...
# 35059  35060  2017      2   28    19   27.0  72.0   8.0  92.0   800.0  16.0
# 35060  35061  2017      2   28    20   47.0  55.0  17.0  86.0  1100.0  19.0
# 35061  35062  2017      2   28    21   18.0  28.0   4.0  30.0   500.0  64.0
# 35062  35063  2017      2   28    22   18.0  20.0   9.0  33.0   500.0  59.0
# 35063  35064  2017      2   28    23   15.0  22.0  13.0  34.0   500.0  60.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM station
# ...

# %%
data_tiantan_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Dataset Final Project Dicoding/Air-quality-dataset/PRSA_Data_20130301-20170228/PRSA_Data_Tiantan_20130301-20170228.csv')
data_tiantan_df
# Out:
#           No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  \
# 0          1  2013      3    1     0    6.0   6.0  4.0   8.0  300.0  81.0
# 1          2  2013      3    1     1    6.0  29.0  5.0   9.0  300.0  80.0
# 2          3  2013      3    1     2    6.0   6.0  4.0  12.0  300.0  75.0
# 3          4  2013      3    1     3    6.0   6.0  4.0  12.0  300.0  74.0
# 4          5  2013      3    1     4    5.0   5.0  7.0  15.0  400.0  70.0
# ...      ...   ...    ...  ...   ...    ...   ...  ...   ...    ...   ...
# 35059  35060  2017      2   28    19   20.0  48.0  2.0   NaN  500.0   NaN
# 35060  35061  2017      2   28    20   11.0  34.0  3.0  36.0  500.0   NaN
# 35061  35062  2017      2   28    21   18.0  32.0  4.0  48.0  500.0  48.0
# 35062  35063  2017      2   28    22   15.0  42.0  5.0  52.0  600.0  44.0
# 35063  35064  2017      2   28    23   15.0  50.0  5.0  68.0  700.0  21.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM  station
# ...

# %%
data_wanliu_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Dataset Final Project Dicoding/Air-quality-dataset/PRSA_Data_20130301-20170228/PRSA_Data_Wanliu_20130301-20170228.csv')
data_wanliu_df
# Out:
#           No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  \
# 0          1  2013      3    1     0    8.0   8.0  6.0  28.0  400.0  52.0
# 1          2  2013      3    1     1    9.0   9.0  6.0  28.0  400.0  50.0
# 2          3  2013      3    1     2    3.0   6.0  NaN  19.0  400.0  55.0
# 3          4  2013      3    1     3   11.0  30.0  8.0  14.0    NaN   NaN
# 4          5  2013      3    1     4    3.0  13.0  9.0   NaN  300.0  54.0
# ...      ...   ...    ...  ...   ...    ...   ...  ...   ...    ...   ...
# 35059  35060  2017      2   28    19   11.0  27.0  4.0  20.0  300.0  81.0
# 35060  35061  2017      2   28    20   15.0  43.0  6.0  55.0  500.0  45.0
# 35061  35062  2017      2   28    21   13.0  35.0  7.0  48.0  500.0  48.0
# 35062  35063  2017      2   28    22   12.0  31.0  5.0  47.0  500.0  50.0
# 35063  35064  2017      2   28    23    7.0  25.0  6.0  86.0  700.0  11.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM station
# ...

# %%
data_wanshouxigong_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Dataset Final Project Dicoding/Air-quality-dataset/PRSA_Data_20130301-20170228/PRSA_Data_Wanshouxigong_20130301-20170228.csv')
data_wanshouxigong_df
# Out:
#           No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  \
# 0          1  2013      3    1     0    9.0   9.0  6.0  17.0  200.0  62.0
# 1          2  2013      3    1     1   11.0  11.0  7.0  14.0  200.0  66.0
# 2          3  2013      3    1     2    8.0   8.0  NaN  16.0  200.0  59.0
# 3          4  2013      3    1     3    8.0   8.0  3.0  16.0    NaN   NaN
# 4          5  2013      3    1     4    8.0   8.0  3.0   NaN  300.0  36.0
# ...      ...   ...    ...  ...   ...    ...   ...  ...   ...    ...   ...
# 35059  35060  2017      2   28    19   11.0  32.0  3.0  24.0  400.0  72.0
# 35060  35061  2017      2   28    20   13.0  32.0  3.0  41.0  500.0  50.0
# 35061  35062  2017      2   28    21   14.0  28.0  4.0  38.0  500.0  54.0
# 35062  35063  2017      2   28    22   12.0  23.0  4.0  30.0  400.0  59.0
# 35063  35064  2017      2   28    23   13.0  19.0  4.0  38.0  600.0  49.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM        station
# ...

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# #### Data Aotizhongxin

# %%
data_aotizhongxin_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34139 non-null  float64
#  6   PM10     34346 non-null  float64
#  7   SO2      34129 non-null  float64
#  8   NO2      34041 non-null  float64
#  9   CO       33288 non-null  float64
#  10  O3       33345 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
data_aotizhongxin_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       925
# PM10        718
# SO2         935
# NO2        1023
# CO         1776
# O3         1719
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           81
# WSPM         14
# station       0
# dtype: int64

# %%
data_aotizhongxin_df.duplicated().sum()
# Out:
# 0

# %%
data_aotizhongxin_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34139.000000  34346.000000  34129.000000  34041.000000  33288.000000
# mean      82.773611    110.060391     17.375901     59.305833   1262.945145
# ...

# %% [markdown]
# #### Data Changping

# %%
data_changping_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34290 non-null  float64
#  6   PM10     34482 non-null  float64
#  7   SO2      34436 non-null  float64
#  8   NO2      34397 non-null  float64
#  9   CO       33543 non-null  float64
#  10  O3       34460 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
data_changping_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       774
# PM10        582
# SO2         628
# NO2         667
# CO         1521
# O3          604
# TEMP         53
# PRES         50
# DEWP         53
# RAIN         51
# wd          140
# WSPM         43
# station       0
# dtype: int64

# %%
data_changping_df.duplicated().sum()
# Out:
# 0

# %%
data_changping_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34290.000000  34482.000000  34436.000000  34397.000000  33543.000000
# mean      71.099743     94.657871     14.958906     44.182086   1152.301345
# ...

# %% [markdown]
# #### Data Dingling

# %%
data_dingling_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34285 non-null  float64
#  6   PM10     34408 non-null  float64
#  7   SO2      34334 non-null  float64
#  8   NO2      33830 non-null  float64
#  9   CO       33052 non-null  float64
#  10  O3       33850 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
data_dingling_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       779
# PM10        656
# SO2         730
# NO2        1234
# CO         2012
# O3         1214
# TEMP         53
# PRES         50
# DEWP         53
# RAIN         51
# wd          140
# WSPM         43
# station       0
# dtype: int64

# %%
data_dingling_df.duplicated().sum()
# Out:
# 0

# %%
data_dingling_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34285.000000  34408.000000  34334.000000  33830.000000  33052.000000
# mean      65.989497     83.739723     11.749650     27.585467    904.896073
# ...

# %% [markdown]
# #### Data Dongsi

# %%
data_dongsi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34314 non-null  float64
#  6   PM10     34511 non-null  float64
#  7   SO2      34401 non-null  float64
#  8   NO2      33463 non-null  float64
#  9   CO       31867 non-null  float64
#  10  O3       34400 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
data_dongsi_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       750
# PM10        553
# SO2         663
# NO2        1601
# CO         3197
# O3          664
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           78
# WSPM         14
# station       0
# dtype: int64

# %%
data_dongsi_df.duplicated().sum()
# Out:
# 0

# %%
data_dongsi_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34314.000000  34511.000000  34401.000000  33463.000000  31867.000000
# mean      86.194297    110.336742     18.531107     53.699443   1330.069131
# ...

# %% [markdown]
# #### Data Guanyuan

# %%
data_guanyuan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34448 non-null  float64
#  6   PM10     34635 non-null  float64
#  7   SO2      34590 non-null  float64
#  8   NO2      34405 non-null  float64
#  9   CO       33311 non-null  float64
#  10  O3       33891 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
data_guanyuan_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       616
# PM10        429
# SO2         474
# NO2         659
# CO         1753
# O3         1173
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           81
# WSPM         14
# station       0
# dtype: int64

# %%
data_guanyuan_df.duplicated().sum()
# Out:
# 0

# %%
data_guanyuan_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34448.000000  34635.000000  34590.000000  34405.000000  33311.000000
# mean      82.933372    109.023303     17.590941     57.901643   1271.294377
# ...

# %% [markdown]
# #### Data Gucheng

# %%
data_gucheng_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34418 non-null  float64
#  6   PM10     34683 non-null  float64
#  7   SO2      34557 non-null  float64
#  8   NO2      34396 non-null  float64
#  9   CO       33663 non-null  float64
#  10  O3       34335 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35013 non-null  float64
#  14  RAIN     35021 non-null  float64
#  15  wd       34905 non-null  object
#  16  WSPM     35022 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
data_gucheng_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       646
# PM10        381
# SO2         507
# NO2         668
# CO         1401
# O3          729
# TEMP         51
# PRES         50
# DEWP         51
# RAIN         43
# wd          159
# WSPM         42
# station       0
# dtype: int64

# %%
data_gucheng_df.duplicated().sum()
# Out:
# 0

# %%
data_gucheng_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34418.000000  34683.000000  34557.000000  34396.000000  33663.000000
# mean      83.852089    118.861978     15.366162     55.871075   1323.974423
# ...

# %% [markdown]
# #### Data Huairou

# %%
data_huairou_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34111 non-null  float64
#  6   PM10     34287 non-null  float64
#  7   SO2      34084 non-null  float64
#  8   NO2      33425 non-null  float64
#  9   CO       33642 non-null  float64
#  10  O3       33913 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35011 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35009 non-null  float64
#  15  wd       34762 non-null  object
#  16  WSPM     35015 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
data_huairou_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       953
# PM10        777
# SO2         980
# NO2        1639
# CO         1422
# O3         1151
# TEMP         51
# PRES         53
# DEWP         53
# RAIN         55
# wd          302
# WSPM         49
# station       0
# dtype: int64

# %%
data_huairou_df.duplicated().sum()
# Out:
# 0

# %%
data_huairou_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34111.000000  34287.000000  34084.000000  33425.000000  33642.000000
# mean      69.626367     91.482690     12.121553     32.497250   1022.554545
# ...

# %% [markdown]
# #### Data Nongzhanguan

# %%
data_nongzhanguan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34436 non-null  float64
#  6   PM10     34624 non-null  float64
#  7   SO2      34618 non-null  float64
#  8   NO2      34372 non-null  float64
#  9   CO       33858 non-null  float64
#  10  O3       34558 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
data_nongzhanguan_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       628
# PM10        440
# SO2         446
# NO2         692
# CO         1206
# O3          506
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           78
# WSPM         14
# station       0
# dtype: int64

# %%
data_nongzhanguan_df.duplicated().sum()
# Out:
# 0

# %%
data_nongzhanguan_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34436.000000  34624.000000  34618.000000  34372.000000  33858.000000
# mean      84.838483    108.991096     18.689242     58.097172   1324.350198
# ...

# %% [markdown]
# #### Data Shunyi

# %%
data_shunyi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34151 non-null  float64
#  6   PM10     34516 non-null  float64
#  7   SO2      33768 non-null  float64
#  8   NO2      33699 non-null  float64
#  9   CO       32886 non-null  float64
#  10  O3       33575 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35013 non-null  float64
#  13  DEWP     35010 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34581 non-null  object
#  16  WSPM     35020 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
data_shunyi_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       913
# PM10        548
# SO2        1296
# NO2        1365
# CO         2178
# O3         1489
# TEMP         51
# PRES         51
# DEWP         54
# RAIN         51
# wd          483
# WSPM         44
# station       0
# dtype: int64

# %%
data_shunyi_df.duplicated().sum()
# Out:
# 0

# %%
data_shunyi_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34151.000000  34516.000000  33768.000000  33699.000000  32886.000000
# mean      79.491602     98.737026     13.572039     43.908865   1187.063979
# ...

# %% [markdown]
# #### Data Tiantan

# %%
data_tiantan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34387 non-null  float64
#  6   PM10     34467 non-null  float64
#  7   SO2      33946 non-null  float64
#  8   NO2      34320 non-null  float64
#  9   CO       33938 non-null  float64
#  10  O3       34221 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
data_tiantan_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       677
# PM10        597
# SO2        1118
# NO2         744
# CO         1126
# O3          843
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           78
# WSPM         14
# station       0
# dtype: int64

# %%
data_tiantan_df.duplicated().sum()
# Out:
# 0

# %%
data_tiantan_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34387.000000  34467.000000  33946.000000  34320.000000  33938.000000
# mean      82.164911    106.363672     14.367615     53.162646   1298.303318
# ...

# %% [markdown]
# #### Data Wanliu

# %%
data_wanliu_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34682 non-null  float64
#  6   PM10     34780 non-null  float64
#  7   SO2      34489 non-null  float64
#  8   NO2      33994 non-null  float64
#  9   CO       33252 non-null  float64
#  10  O3       32957 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34941 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
data_wanliu_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       382
# PM10        284
# SO2         575
# NO2        1070
# CO         1812
# O3         2107
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd          123
# WSPM         14
# station       0
# dtype: int64

# %%
data_wanliu_df.duplicated().sum()
# Out:
# 0

# %%
data_wanliu_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34682.000000  34780.000000  34489.000000  33994.000000  33252.000000
# mean      83.374716    110.464618     18.376481     65.258789   1319.353513
# ...

# %% [markdown]
# #### Data Wanshouxigong

# %%
data_wanshouxigong_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34368 non-null  float64
#  6   PM10     34580 non-null  float64
#  7   SO2      34395 non-null  float64
#  8   NO2      34310 non-null  float64
#  9   CO       33767 non-null  float64
#  10  O3       33986 non-null  float64
#  11  TEMP     35045 non-null  float64
#  12  PRES     35045 non-null  float64
#  13  DEWP     35045 non-null  float64
#  14  RAIN     35045 non-null  float64
#  15  wd       34985 non-null  object
#  16  WSPM     35051 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
data_wanshouxigong_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       696
# PM10        484
# SO2         669
# NO2         754
# CO         1297
# O3         1078
# TEMP         19
# PRES         19
# DEWP         19
# RAIN         19
# wd           79
# WSPM         13
# station       0
# dtype: int64

# %%
data_wanshouxigong_df.duplicated().sum()
# Out:
# 0

# %%
data_wanshouxigong_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2          NO2            CO  \
# count  34368.000000  34580.000000  34395.000000  34310.00000  33767.000000
# mean      85.024136    112.223459     17.148603     55.52956   1370.395031
# ...

# %%
data_types = data_aotizhongxin_df.dtypes

print(data_types)

data_types_df = data_types.to_frame().T

print(data_types_df)
# Out:
# No           int64
# year         int64
# month        int64
# day          int64
# hour         int64
# PM2.5      float64
# PM10       float64
# SO2        float64
# NO2        float64
# CO         float64
# O3         float64
# TEMP       float64
# PRES       float64
# DEWP       float64
# RAIN       float64
# wd          object
# WSPM       float64
# station     object
# dtype: object
#       No   year  month    day   hour    PM2.5     PM10      SO2      NO2  \
# 0  int64  int64  int64  int64  int64  float64  float64  float64  float64
#
#         CO       O3     TEMP     PRES     DEWP     RAIN      wd     WSPM  \
# 0  float64  float64  float64  float64  float64  float64  object  float64
#
#   station
# 0  object

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# Mengisi nilai kosong pada kolom 'CO', 'PM2.5', 'PM10', 'SO2', 'NO2', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'WSPM' dengan metode imputation. Serta mengisi nilai 'wd' dengan menggunakan nilai dominan dari kolom wd

# %%
def fill_missing_values(df):
  column_to_fill = ['CO', 'PM2.5', 'PM10', 'SO2', 'NO2', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'WSPM']
  non_num_column = ['wd']
  df[column_to_fill] = df[column_to_fill].apply(lambda x: x.fillna(x.mean()), axis=0)

  df[non_num_column] = df[non_num_column].fillna('wd')

  return df

# %% [markdown]
# Apply function full_missing_values untuk setiap dataframe

# %%
data_aotizhongxin_df = fill_missing_values(data_aotizhongxin_df)
data_changping_df = fill_missing_values(data_changping_df)
data_dingling_df = fill_missing_values(data_dingling_df)
data_dongsi_df = fill_missing_values(data_dongsi_df)
data_guanyuan_df = fill_missing_values(data_guanyuan_df)
data_gucheng_df = fill_missing_values(data_gucheng_df)
data_huairou_df = fill_missing_values(data_huairou_df)
data_nongzhanguan_df = fill_missing_values(data_nongzhanguan_df)
data_shunyi_df = fill_missing_values(data_shunyi_df)
data_tiantan_df = fill_missing_values(data_tiantan_df)
data_wanliu_df = fill_missing_values(data_wanliu_df)
data_wanshouxigong_df = fill_missing_values(data_wanshouxigong_df)

# %% [markdown]
# Pengecekan kualitas data terakhir

# %%
print(data_aotizhongxin_df.isna().sum())
print(data_changping_df.isna().sum())
print(data_dingling_df.isna().sum())
print(data_dongsi_df.isna().sum())
print(data_guanyuan_df.isna().sum())
print(data_gucheng_df.isna().sum())
print(data_huairou_df.isna().sum())
print(data_nongzhanguan_df.isna().sum())
print(data_shunyi_df.isna().sum())
print(data_tiantan_df.isna().sum())
print(data_wanliu_df.isna().sum())
print(data_wanshouxigong_df.isna().sum())
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# ...

# %% [markdown]
# Konversi kolom 'year', 'month', 'day', 'hour' menjadi kolom 'Datetime' dengan menggunakan library pandas .to_datettime

# %%
list_df = [
  data_aotizhongxin_df,
  data_changping_df,
  data_dingling_df,
  data_dongsi_df,
  data_guanyuan_df,
  data_gucheng_df,
  data_huairou_df,
  data_nongzhanguan_df,
  data_shunyi_df,
  data_tiantan_df,
  data_wanliu_df,
  data_wanshouxigong_df
]

for data in list_df:
    data['Datetime'] = pd.to_datetime(data[['year', 'month', 'day', 'hour']])
    data.drop(columns=['year', 'month', 'day', 'hour', 'No'], inplace=True)

# %% [markdown]
# Penggabungan keselurahan dataframe menjadi 1

# %%
all_data = pd.concat(list_df, ignore_index=True)

# %%
all_data
# Out:
#         PM2.5  PM10   SO2   NO2     CO    O3  TEMP    PRES  DEWP  RAIN   wd  \
# 0         4.0   4.0   4.0   7.0  300.0  77.0  -0.7  1023.0 -18.8   0.0  NNW
# 1         8.0   8.0   4.0   7.0  300.0  77.0  -1.1  1023.2 -18.2   0.0    N
# 2         7.0   7.0   5.0  10.0  300.0  73.0  -1.1  1023.5 -18.2   0.0  NNW
# 3         6.0   6.0  11.0  11.0  300.0  72.0  -1.4  1024.5 -19.4   0.0   NW
# 4         3.0   3.0  12.0  12.0  300.0  72.0  -2.0  1025.2 -19.5   0.0    N
# ...       ...   ...   ...   ...    ...   ...   ...     ...   ...   ...  ...
# 420763   11.0  32.0   3.0  24.0  400.0  72.0  12.5  1013.5 -16.2   0.0   NW
# 420764   13.0  32.0   3.0  41.0  500.0  50.0  11.6  1013.6 -15.1   0.0  WNW
# 420765   14.0  28.0   4.0  38.0  500.0  54.0  10.8  1014.2 -13.3   0.0   NW
# 420766   12.0  23.0   4.0  30.0  400.0  59.0  10.5  1014.4 -12.9   0.0  NNW
# 420767   13.0  19.0   4.0  38.0  600.0  49.0   8.6  1014.1 -15.9   0.0  NNE
#
#         WSPM        station            Datetime
# ...

# %%
data_aotizhongxin_df
# Out:
#        PM2.5  PM10   SO2   NO2     CO    O3  TEMP    PRES  DEWP  RAIN   wd  \
# 0        4.0   4.0   4.0   7.0  300.0  77.0  -0.7  1023.0 -18.8   0.0  NNW
# 1        8.0   8.0   4.0   7.0  300.0  77.0  -1.1  1023.2 -18.2   0.0    N
# 2        7.0   7.0   5.0  10.0  300.0  73.0  -1.1  1023.5 -18.2   0.0  NNW
# 3        6.0   6.0  11.0  11.0  300.0  72.0  -1.4  1024.5 -19.4   0.0   NW
# 4        3.0   3.0  12.0  12.0  300.0  72.0  -2.0  1025.2 -19.5   0.0    N
# ...      ...   ...   ...   ...    ...   ...   ...     ...   ...   ...  ...
# 35059   12.0  29.0   5.0  35.0  400.0  95.0  12.5  1013.5 -16.2   0.0   NW
# 35060   13.0  37.0   7.0  45.0  500.0  81.0  11.6  1013.6 -15.1   0.0  WNW
# 35061   16.0  37.0  10.0  66.0  700.0  58.0  10.8  1014.2 -13.3   0.0   NW
# 35062   21.0  44.0  12.0  87.0  700.0  35.0  10.5  1014.4 -12.9   0.0  NNW
# 35063   19.0  31.0  10.0  79.0  600.0  42.0   8.6  1014.1 -15.9   0.0  NNE
#
#        WSPM       station            Datetime
# ...

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %% [markdown]
# Eksplore perbedaan dari data menggunakan f_oneway pada variabel 'CO', 'SO2', 'NO2', 'O3'

# %%
variable_to_analyze = ['CO', 'SO2', 'NO2', 'O3']

for variable in variable_to_analyze:
  data_stations = [df[variable] for df in list_df]
  statistic, p_value = f_oneway(*data_stations)
  alpha = 0.05
  if p_value < alpha:
      print(f"Terdapat perbedaan signifikan dalam {variable} antara stasiun-stasiun")
  else:
      print(f"Tidak ada perbedaan signifikan dalam {variable} antara stasiun-stasiun")
# Out:
# Terdapat perbedaan signifikan dalam CO antara stasiun-stasiun
# Terdapat perbedaan signifikan dalam SO2 antara stasiun-stasiun
# Terdapat perbedaan signifikan dalam NO2 antara stasiun-stasiun
# Terdapat perbedaan signifikan dalam O3 antara stasiun-stasiun

# %%
combined_data = all_data

# %%
combined_data.describe()
# Out:
#                PM2.5           PM10            SO2            NO2  \
# count  420768.000000  420768.000000  420768.000000  420768.000000
# mean       79.780235     104.578547      15.820683      50.583319
# std        79.984694      91.075152      21.420157      34.677400
# min         2.000000       2.000000       0.285600       1.026500
# 25%        21.000000      36.000000       3.000000      24.000000
# 50%        57.000000      83.739723       8.000000      44.000000
# 75%       109.000000     144.000000      19.000000      70.000000
# max       999.000000     999.000000     500.000000     290.000000
#
#                  CO             O3           TEMP           PRES  \
# count  420768.00000  420768.000000  420768.000000  420768.000000
# mean     1230.62509      57.349235      13.538931    1010.746341
# std      1131.69545      55.767436      11.430737      10.469404
# min       100.00000       0.214200     -19.900000     982.400000
# ...

# %% [markdown]
# Pivot dengan 4 parameter dan mean masing-masing parameter dengan pusat nya berada di parameter station

# %%
combined_data.groupby(by="station").agg({
    "SO2": ["mean"],
    "NO2": ["mean"],
    "CO": ["mean"],
    "O3": ["mean"]
})
# Out:
#                      SO2        NO2           CO         O3
#                     mean       mean         mean       mean
# station
# Aotizhongxin   17.375901  59.305833  1262.945145  56.353358
# Changping      14.958906  44.182086  1152.301345  57.940003
# Dingling       11.749650  27.585467   904.896073  68.548371
# Dongsi         18.531107  53.699443  1330.069131  57.210637
# Guanyuan       17.590941  57.901643  1271.294377  55.795044
# Gucheng        15.366162  55.871075  1323.974423  57.694879
# Huairou        12.121553  32.497250  1022.554545  59.824713
# Nongzhanguan   18.689242  58.097172  1324.350198  58.534682
# Shunyi         13.572039  43.908865  1187.063979  55.201321
# Tiantan        14.367615  53.162646  1298.303318  55.984297
# Wanliu         18.376481  65.258789  1319.353513  48.873614
# Wanshouxigong  17.148603  55.529560  1370.395031  56.229904

# %% [markdown]
# Perhitungan total polusi masing-masing station

# %%
pollutant_mean = combined_data.groupby(by="station").agg({
    "SO2": ["mean"],
    "NO2": ["mean"],
    "CO": ["mean"],
    "O3": ["mean"]
})

pollutant_mean['Pollution Levels'] = pollutant_mean.mean(axis=1)

print(pollutant_mean)
# Out:
#                      SO2        NO2           CO         O3 Pollution Levels
#                     mean       mean         mean       mean
# station
# Aotizhongxin   17.375901  59.305833  1262.945145  56.353358       348.995060
# Changping      14.958906  44.182086  1152.301345  57.940003       317.345585
# Dingling       11.749650  27.585467   904.896073  68.548371       253.194890
# Dongsi         18.531107  53.699443  1330.069131  57.210637       364.877579
# Guanyuan       17.590941  57.901643  1271.294377  55.795044       350.645501
# Gucheng        15.366162  55.871075  1323.974423  57.694879       363.226635
# Huairou        12.121553  32.497250  1022.554545  59.824713       281.749515
# Nongzhanguan   18.689242  58.097172  1324.350198  58.534682       364.917824
# Shunyi         13.572039  43.908865  1187.063979  55.201321       324.936551
# Tiantan        14.367615  53.162646  1298.303318  55.984297       355.454469
# ...

# %% [markdown]
# Pivot table dengan parameter Temp dan Rain

# %%
volume_mean = combined_data.groupby(by="station").agg({
    "TEMP": ["max", "min"],
    "RAIN": ["max", "min"],
})
volume_mean
# Out:
#                TEMP        RAIN
#                 max   min   max  min
# station
# Aotizhongxin   40.5 -16.8  72.5  0.0
# Changping      41.4 -16.6  52.1  0.0
# Dingling       41.4 -16.6  52.1  0.0
# Dongsi         41.1 -16.8  46.4  0.0
# Guanyuan       40.5 -16.8  72.5  0.0
# Gucheng        41.6 -15.6  41.9  0.0
# Huairou        40.3 -19.9  45.9  0.0
# Nongzhanguan   41.1 -16.8  46.4  0.0
# Shunyi         40.6 -16.8  37.3  0.0
# Tiantan        41.1 -16.8  46.4  0.0
# Wanliu         40.5 -15.8  72.5  0.0
# Wanshouxigong  40.6 -16.8  46.4  0.0

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Apakah ada perbedaan signifikan dalam kualitas udara antara stasiun-stasiun yang berbeda?

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x='station', y='SO2', data=combined_data, color='skyblue')
plt.xticks(rotation=45)
plt.xlabel('Stasiun')
plt.ylim(0,25)
plt.ylabel('SO2')
plt.title('Bar Plot Perbandingan SO2 di Antara Stasiun')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x='station', y='NO2', data=combined_data, color='skyblue')
plt.xticks(rotation=45)
plt.xlabel('Stasiun')
plt.ylim(0,75)
plt.ylabel('NO2')
plt.title('Bar Plot Perbandingan NO2 di Antara Stasiun')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x='station', y='CO', data=combined_data, color='skyblue')
plt.xticks(rotation=45)
plt.xlabel('Stasiun')
plt.ylim(0,1600)
plt.ylabel('CO')
plt.title('Bar Plot Perbandingan CO di Antara Stasiun')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x='station', y='O3', data=combined_data, color='skyblue')
plt.xticks(rotation=45)
plt.xlabel('Stasiun')
plt.ylim(0,80)
plt.ylabel('O3')
plt.title('Bar Plot Perbandingan O3 di Antara Stasiun')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x='station', y='Pollution Levels', data=pollutant_mean, color='skyblue')
plt.xticks(rotation=45)
plt.xlabel('Stasiun')
plt.ylim(0,450)
plt.ylabel('Pollution Levels')
plt.title('Bar Plot Perbandingan Pollution Levels di Antara Stasiun')
plt.show()

# %% [markdown]
# ### Pertanyaan 2: Pada stasiun mana suhu mencapai derajat terendah dan tertingginya?

# %%
stations = volume_mean.index
max_temp_levels = volume_mean['TEMP']['max']
min_temp_levels = volume_mean['TEMP']['min']

bar_width = 0.35

r1 = range(len(stations))
r2 = [x + bar_width for x in r1]

plt.figure(figsize=(12, 6))
plt.bar(r1, max_temp_levels, color='skyblue', width=bar_width, edgecolor='grey', label='Max Temperature')
plt.bar(r2, min_temp_levels, color='lightgreen', width=bar_width, edgecolor='grey', label='Min Temperature')

plt.xlabel('Station Name', fontsize=14)
plt.ylabel('Temperature Level', fontsize=14)
plt.title('Max and Min Temperature Levels per Station', fontsize=16)
plt.xticks([r + bar_width/2 for r in range(len(stations))], stations, rotation=45, ha='right')

plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Apakah ada perbedaan signifikan dalam kualitas udara antara stasiun-stasiun yang berbeda?
#
# 1.   SO2 (Sulfur Dioxide):
#   - Highest: Wanshouxigong with a mean of 17.15
#   - Lowest: Huairou with a mean of 12.12
#
# 2. NO2 (Nitrogen Dioxide):
#   - Highest: Wanliu with a mean of 65.26
#   -Lowest: Dingling with a mean of 27.59
#
# 3. CO (Carbon Monoxide):
#   - Highest: Wanliu with a mean of 1370.40
#   - Lowest: Dingling with a mean of 904.90
#
# 4. O3 (Ozone):
#   - Highest: Dingling with a mean of 68.55
#   - Lowest: Wanliu with a mean of 48.87
#
# 5. Pollution Levels (Combined):
#   - Highest: Wanshouxigong with a mean of 374.83
#   - Lowest: Dingling with a mean of 253.19
#
#
#
# - Pada stasiun mana suhu mencapai derajat terendah dan tertingginya?
#
# Suhu tertinggi terjadi pada stasiun Gucheng sedangkan suhu terendah terjadi pada stasiun Wanliu.

# %%
all_data.to_csv("all_data.csv", index=False)
